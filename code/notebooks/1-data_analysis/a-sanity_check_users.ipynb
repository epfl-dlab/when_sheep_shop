# %%
import os
os.chdir('../..')

# %%
import numpy as np
import json
import pandas as pd
import time

import statsmodels.api as sm

import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import matplotlib
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

from classes.helpers import *

# For the Python notebook
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
df = pd.read_csv('../data/ba/users.csv')

# %%
joined_date = np.array(df['joined'])

joined_year = []
for d in joined_date:
    try:
        joined_year.append(int(time.gmtime(int(d)).tm_year))
    except:
        joined_year.append(0)
        
joined_year = np.array(joined_year)

# %%
df_2014 = df[joined_year == 2014]

# %%
df_2014['nbr_ratings'].describe()
# Out:
# count    42789.000000
# mean        25.096006
# std        116.206047
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          8.000000
# max       4428.000000
# Name: nbr_ratings, dtype: float64

# %%
df_2014['nbr_reviews'].describe()
# Out:
# count    42789.000000
# mean         2.314567
# std         25.996854
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       1728.000000
# Name: nbr_reviews, dtype: float64

# %%
df_2014[(df_2014['nbr_reviews'] == 0) & (df_2014['nbr_ratings'] == 1)]
# Out:
#         nbr_ratings  nbr_reviews                 user_id        user_name  \
# 628               1            0           hb_sol.776883           hb_sol
# 673               1            0     lapalco_mike.866396     lapalco_mike
# 735               1            0      sintaroldus.842328      SintAroldus
# 1469              1            0         ryanbiln.908784         Ryanbiln
# 2209              1            0          tbaum05.855423          tbaum05
# 3079              1            0         andyshea.862302         Andyshea
# 3130              1            0      wirelesstom.916663      WirelessTom
# 3148              1            0           kletus.897354           Kletus
# 3230              1            0     flyinryan167.813046     flyinryan167
# 3739              1            0       ph_mariano.829950       Ph_mariano
# 4215              1            0        rlundback.857612        rlundback
# 4457              1            0        jzy063083.899402        jzy063083
# ...
